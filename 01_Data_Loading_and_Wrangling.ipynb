# %% [markdown]
# # Data Loading and Wrangling
#
# **Project:** Time Series Modeling of Air Quality in Nairobi
#
# **Institution:** WorldQuant University

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Add your code and analysis here.
